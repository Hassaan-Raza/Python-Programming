# %% [raw]
# Shallow Copy VS Deep Copy Python
#
# =, copy(), deepcopy()
#
# Always consider the datatype because elements of collections are mutable and they should also have this mutability property itself

# %%
lst1=[1,2,3,4]
lst2=lst1

# %% [raw]
# Equal works like a pointer in C++. lst2 basically stores the address to lst1 and any changes done in lst2 will reflect in lst1

# %% [raw]
# Copy operation
#
# It s a kind of shallow copy

# %%
lst3=lst1.copy()

# %%
lst3
# Out:
# [1, 2, 3, 4]

# %% [raw]
# if we use .copy(), it copies the values of lst1 and then stores it in lst3 where it can be changed independently without worrying about lst1

# %% [raw]
# Shallow copy with respect to nested list

# %%
lst4=[[1,2,3],[4,5,6,],[7,8,9]]

# %%
lst5=lst4.copy()

# %%
lst4
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
lst5
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
lst5[1][0]=90

# %%
lst5
# Out:
# [[1, 2, 3], [90, 5, 6], [7, 8, 9]]

# %%
lst4
# Out:
# [[1, 2, 3], [90, 5, 6], [7, 8, 9]]

# %% [raw]
# Deep copy

# %%
import copy
list1=[1,2,3,4]
list2=copy.deepcopy(list1)

# %%
list2[1]
# Out:
# 2

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
list2[1]=100

# %%
list2
# Out:
# [1, 100, 3, 4]

# %% [raw]
# How to make Pandas Faster by 4 times
#
# We use Modin library to do this

# %%
import pandas as pd

# %%
# %%time
df=pd.read_csv('test.csv')
df
# Out:
# CPU times: total: 11.1 s
# Wall time: 29.6 s
#                             file  round    tick    seconds att_team vic_team  \
# 0        esea_match_13818366.dem      1   21257   165.8779   Team 2   Team 1
# 1        esea_match_13818366.dem      1   21653   168.9752   Team 1   Team 2
# 2        esea_match_13818366.dem      1   21717   169.4758   Team 1   Team 2
# 3        esea_match_13818366.dem      1   21937   171.1965   Team 1   Team 2
# 4        esea_match_13818366.dem      1   22229   173.4804   Team 1   Team 2
# ...                          ...    ...     ...        ...      ...      ...
# 4546080  esea_match_13829173.dem     22  243361  1901.4210   Team 1   Team 2
# 4546081  esea_match_13829173.dem     22  243373  1901.5150   Team 1   Team 2
# 4546082  esea_match_13829173.dem     22  243405  1901.7650   Team 2   Team 1
# 4546083  esea_match_13829173.dem     22  243719  1904.2230   Team 2   Team 1
# 4546084  esea_match_13829173.dem     22  243755  1904.5050   Team 1   Team 2
#
# ...

# %%
df.groupby('att_team')

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 1.83 s
# Wall time: 3.46 s
#                          file    round     tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--      647      647      647      647       647       647
# ALTERNATE aTTaX           791      791      791      791       791       791
# BOOT-dS Letou             610      610      610      610       610       610
# Cerus eSports             338      338      338      338       338       338
# Chiefs                    823      823      823      823       823       823
# Dynasty                   710      710      710      710       710       710
# FlashGaming               660      660      660      660       660       660
# Grayhound                 759      759      759      759       759       759
# Ground Zero               720      720      720      720       720       720
# Guerrilla Tactics         350      350      350      350       350       350
# ...

# %%
import modin.pandas as pd

# %%
# %%time
df=pd.read_csv('test.csv')
df
# Out:
# 2024-07-29 21:19:41,751	INFO worker.py:1781 -- Started a local Ray instance.
# CPU times: total: 1.44 s
# Wall time: 26.6 s
#                             file  round    tick    seconds att_team vic_team  \
# 0        esea_match_13818366.dem      1   21257   165.8779   Team 2   Team 1
# 1        esea_match_13818366.dem      1   21653   168.9752   Team 1   Team 2
# 2        esea_match_13818366.dem      1   21717   169.4758   Team 1   Team 2
# 3        esea_match_13818366.dem      1   21937   171.1965   Team 1   Team 2
# 4        esea_match_13818366.dem      1   22229   173.4804   Team 1   Team 2
# ...                          ...    ...     ...        ...      ...      ...
# 4546080  esea_match_13829173.dem     22  243361  1901.4210   Team 1   Team 2
# 4546081  esea_match_13829173.dem     22  243373  1901.5150   Team 1   Team 2
# 4546082  esea_match_13829173.dem     22  243405  1901.7650   Team 2   Team 1
# 4546083  esea_match_13829173.dem     22  243719  1904.2230   Team 2   Team 1
# ...

# %%
# %%time
df.groupby('att_team').count()

# %% [raw]
# Class Methods and Class Variables

# %%
class Car:
    base_price=10000
    def __init__(self,windows,doors,power):
        self.windows=windows
        self.doors=doors
        self.power=power
    def what_base_price(self):
        print(f"The base price is {self.base_price}")
    @classmethod
    def revise_base_price(cls,inflation):
        cls.base_price=cls.base_price+cls.base_price*inflation

# %% [raw]
# Class Variable
#
# base_price

# %%
car1=Car(4,4,1000)
car1.base_price
# Out:
# 10000

# %%
car1.what_base_price()
# Out:
# The base price is 11000.0

# %%
Car.revise_base_price(0.10)

# %%
Car.base_price
# Out:
# 11000.0

# %% [raw]
# Basically Class method is used to manipulate the class variable for every single instance, meaning every single instance made from this class will have the same value of the class variable
#
# classmethod is a decorator

# %%
car2=Car(3,4,5000)
car2.base_price
# Out:
# 11000.0
